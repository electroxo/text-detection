# %% [markdown]
# <a href="https://colab.research.google.com/github/electroxo/text-detection/blob/main/text_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install matplotlib

# %%
pip install opencv-python-headless

# %%
import cv2
import easyocr
import matplotlib.pyplot as plt

#read image
image_path = '/content/asd2.jpg'
img = cv2.imread(image_path)
#instance text detector
reader = easyocr.Reader(['en'])
#detect text on image
text_ = reader.readtext(img)

threshold = 0.25


#draw bbox and text

for t in text_:
  print(t)

  bbox, text, score = t

  if score > threshold:
   # Convert list coordinates to tuples of integers
   pt1 = (int(bbox[0][0]), int(bbox[0][1]))
   pt2 = (int(bbox[2][0]), int(bbox[2][1]))

  cv2.rectangle(img, pt1, pt2, (0, 255, 0), 5)
  cv2.putText(img, text, pt1, cv2.FONT_HERSHEY_COMPLEX, 0.65, (255, 0, 0), 1)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# ([[np.int32(70), np.int32(204)], [np.int32(212), np.int32(204)], [np.int32(212), np.int32(236)], [np.int32(70), np.int32(236)]], 'Cyclists use', np.float64(0.9951707212264465))
# ([[np.int32(78), np.int32(228)], [np.int32(200), np.int32(228)], [np.int32(200), np.int32(259)], [np.int32(78), np.int32(259)]], 'cycle lane', np.float64(0.8346555526065084))
# ([[np.int32(114), np.int32(254)], [np.int32(168), np.int32(254)], [np.int32(168), np.int32(284)], [np.int32(114), np.int32(284)]], 'only', np.float64(0.9997068643569946))
# ([[np.int32(282), np.int32(376)], [np.int32(393), np.int32(376)], [np.int32(393), np.int32(416)], [np.int32(282), np.int32(416)]], 'Except', np.float64(0.9999628669326995))
# ...
